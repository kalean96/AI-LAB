# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
# %matplotlib inline

# %%
csv = pd.read_csv("imbd_superhero.csv", 
                  header=None, 
                  names=['An', 'Titlu','Organizatia', 'IMBD', 'AltRating', 'DataX', 'UnknownColumn', 'PretMediulaBilet', 'NrDeSpectatori', 'TopPentruAncutare'])
csv.head(8)
# Out:
#      An                             Titlu Organizatia  IMBD  AltRating  DataX  \
# 0  1978                          Superman          DC   7.3         95   84.0
# 1  1980                       Superman II          DC   6.7         88   77.5
# 2  1982                       Swamp Thing          DC   5.3         60   56.5
# 3  1983                      Superman III          DC   4.9         24   36.5
# 4  1984                         Supergirl          DC   4.2          8   25.0
# 5  1986                   Howard the Duck      Marvel   4.3         16   29.5
# 6  1987  Superman IV: The Quest for Peace          DC   3.6         10   23.0
# 7  1989                            Batman          DC   7.6         71   73.5
#
#    UnknownColumn  PretMediulaBilet  NrDeSpectatori  TopPentruAncutare
# 0      7465343.0              2.34    3.190318e+06          222584545
# 1     14100523.0              2.69    5.241830e+06          227224681
# 2            NaN              2.94             NaN          231664458
# 3     13352357.0              3.15    4.238843e+06          233791994
# 4      5738249.0              3.36    1.707812e+06          235824902
# 5      5070136.0              3.71    1.366613e+06          240132887
# 6      5683122.0              3.91    1.453484e+06          242288918
# 7     40489746.0              3.97    1.019893e+07          246819230

# %%
new_csv = csv[np.isfinite(csv.UnknownColumn)].append(csv[np.isfinite(csv.NrDeSpectatori)])

new_csv.head(10)
# Out:
#       An                             Titlu Organizatia  IMBD  AltRating  \
# 0   1978                          Superman          DC   7.3         95
# 1   1980                       Superman II          DC   6.7         88
# 3   1983                      Superman III          DC   4.9         24
# 4   1984                         Supergirl          DC   4.2          8
# 5   1986                   Howard the Duck      Marvel   4.3         16
# 6   1987  Superman IV: The Quest for Peace          DC   3.6         10
# 7   1989                            Batman          DC   7.6         71
# 10  1992                    Batman Returns          DC   7.0         78
# 11  1995                    Batman Forever          DC   5.4         42
# 12  1997                    Batman & Robin          DC   3.6         12
#
#     DataX  UnknownColumn  PretMediulaBilet  NrDeSpectatori  TopPentruAncutare
# 0    84.0      7465343.0              2.34    3.190318e+06          222584545
# 1    77.5     14100523.0              2.69    5.241830e+06          227224681
# 3    36.5     13352357.0              3.15    4.238843e+06          233791994
# 4    25.0      5738249.0              3.36    1.707812e+06          235824902
# 5    29.5      5070136.0              3.71    1.366613e+06          240132887
# 6    23.0      5683122.0              3.91    1.453484e+06          242288918
# 7    73.5     40489746.0              3.97    1.019893e+07          246819230
# 10   74.0     45687711.0              4.15    1.100909e+07          255029699
# 11   48.0     52784433.0              4.35    1.213435e+07          262803276
# 12   24.0     42872605.0              4.59    9.340437e+06          267783607

# %%
#Normalizam scorurile 
imbd_normalizat = new_csv.IMBD/10 #nota imbd din 10
new_csv.insert(10, 'IMBD_normalizat', imbd_normalizat)

# %%
altrating_normalizat = new_csv.AltRating/100 #scorul din 100
new_csv.insert(11, 'AltRating_normalizat', altrating_normalizat)

# %%
new_csv.head()
# Out:
#      An            Titlu Organizatia  IMBD  AltRating  DataX  UnknownColumn  \
# 0  1978         Superman          DC   7.3         95   84.0      7465343.0
# 1  1980      Superman II          DC   6.7         88   77.5     14100523.0
# 3  1983     Superman III          DC   4.9         24   36.5     13352357.0
# 4  1984        Supergirl          DC   4.2          8   25.0      5738249.0
# 5  1986  Howard the Duck      Marvel   4.3         16   29.5      5070136.0
#
#    PretMediulaBilet  NrDeSpectatori  TopPentruAncutare  IMBD_normalizat  \
# 0              2.34     3190317.521          222584545             0.73
# 1              2.69     5241830.112          227224681             0.67
# 3              3.15     4238843.492          233791994             0.49
# 4              3.36     1707812.202          235824902             0.42
# 5              3.71     1366613.477          240132887             0.43
#
#    AltRating_normalizat
# 0                  0.95
# 1                  0.88
# 3                  0.24
# 4                  0.08
# 5                  0.16

# %%
new_csv.plot.scatter(y = 'IMBD_normalizat', x = 'AltRating_normalizat')

# %%
new_csv[['IMBD_normalizat', 'AltRating_normalizat']].corr()
# Out:
#                       IMBD_normalizat  AltRating_normalizat
# IMBD_normalizat               1.00000               0.88836
# AltRating_normalizat          0.88836               1.00000

# %%
new_csv[['IMBD_normalizat', 'AltRating_normalizat']].describe()
# Out:
#        IMBD_normalizat  AltRating_normalizat
# count        92.000000             92.000000
# mean          0.630000              0.539783
# std           0.152056              0.300465
# min           0.270000              0.080000
# 25%           0.540000              0.260000
# 50%           0.665000              0.605000
# 75%           0.740000              0.820000
# max           0.910000              0.950000

# %%
plot = new_csv.plot.scatter(x = 'An', y = 'PretMediulaBilet')
z = np.polyfit(x=new_csv.An, y=new_csv.PretMediulaBilet, deg=5) #polinom de gradul 5 inseamna deg=5
p = np.poly1d(z)
trendline = pd.DataFrame(data=p(new_csv.An), index=new_csv.An)
trendline.plot.line(ax=plot, color='Yellow')

# %%
#Definim serie pandas 
series = csv.iloc[:, :]
print(series.head(10))
# Out:
#      An                             Titlu Organizatia  IMBD  AltRating  DataX  \
# 0  1978                          Superman          DC   7.3         95   84.0
# 1  1980                       Superman II          DC   6.7         88   77.5
# 2  1982                       Swamp Thing          DC   5.3         60   56.5
# 3  1983                      Superman III          DC   4.9         24   36.5
# 4  1984                         Supergirl          DC   4.2          8   25.0
# 5  1986                   Howard the Duck      Marvel   4.3         16   29.5
# 6  1987  Superman IV: The Quest for Peace          DC   3.6         10   23.0
# 7  1989                            Batman          DC   7.6         71   73.5
# 8  1989         The Return of Swamp Thing          DC   3.9         40   39.5
# 9  1989                      The Punisher      Marvel   5.4         24   39.0
#
#    UnknownColumn  PretMediulaBilet  NrDeSpectatori  TopPentruAncutare
# 0      7465343.0              2.34    3.190318e+06          222584545
# 1     14100523.0              2.69    5.241830e+06          227224681
# 2            NaN              2.94             NaN          231664458
# 3     13352357.0              3.15    4.238843e+06          233791994
# 4      5738249.0              3.36    1.707812e+06          235824902
# 5      5070136.0              3.71    1.366613e+06          240132887
# 6      5683122.0              3.91    1.453484e+06          242288918
# 7     40489746.0              3.97    1.019893e+07          246819230
# 8            NaN              3.97             NaN          246819230
# 9            NaN              3.97             NaN          246819230

# %%
#Definim DataFrame
dataframe = pd.DataFrame(csv)
dataframe.head(10)
# Out:
#      An                             Titlu Organizatia  IMBD  AltRating  DataX  \
# 0  1978                          Superman          DC   7.3         95   84.0
# 1  1980                       Superman II          DC   6.7         88   77.5
# 2  1982                       Swamp Thing          DC   5.3         60   56.5
# 3  1983                      Superman III          DC   4.9         24   36.5
# 4  1984                         Supergirl          DC   4.2          8   25.0
# 5  1986                   Howard the Duck      Marvel   4.3         16   29.5
# 6  1987  Superman IV: The Quest for Peace          DC   3.6         10   23.0
# 7  1989                            Batman          DC   7.6         71   73.5
# 8  1989         The Return of Swamp Thing          DC   3.9         40   39.5
# 9  1989                      The Punisher      Marvel   5.4         24   39.0
#
#    UnknownColumn  PretMediulaBilet  NrDeSpectatori  TopPentruAncutare
# 0      7465343.0              2.34    3.190318e+06          222584545
# 1     14100523.0              2.69    5.241830e+06          227224681
# 2            NaN              2.94             NaN          231664458
# 3     13352357.0              3.15    4.238843e+06          233791994
# 4      5738249.0              3.36    1.707812e+06          235824902
# 5      5070136.0              3.71    1.366613e+06          240132887
# 6      5683122.0              3.91    1.453484e+06          242288918
# 7     40489746.0              3.97    1.019893e+07          246819230
# 8            NaN              3.97             NaN          246819230
# 9            NaN              3.97             NaN          246819230

# %%
#filmele de la DC pentru DataFrame-ul new_csv
new_csv.loc[new_csv['Organizatia'] == 'DC']
# Out:
#       An                             Titlu Organizatia  IMBD  AltRating  \
# 0   1978                          Superman          DC   7.3         95
# 1   1980                       Superman II          DC   6.7         88
# 3   1983                      Superman III          DC   4.9         24
# 4   1984                         Supergirl          DC   4.2          8
# 6   1987  Superman IV: The Quest for Peace          DC   3.6         10
# 7   1989                            Batman          DC   7.6         71
# 10  1992                    Batman Returns          DC   7.0         78
# 11  1995                    Batman Forever          DC   5.4         42
# 12  1997                    Batman & Robin          DC   3.6         12
# 13  1997                             Steel          DC   2.7         12
# 22  2004                          Catwoman          DC   3.2         10
# 25  2005                     Batman Begins          DC   8.3         85
# 28  2006                  Superman Returns          DC   6.3         76
# 33  2008                   The Dark Knight          DC   8.9         94
# 37  2009                          Watchmen          DC   7.7         64
# 40  2010                         Jonah Hex          DC   4.6         13
# 42  2011                     Green Lantern          DC   5.9         27
# 46  2012             The Dark Knight Rises          DC   9.1         86
# 0   1978                          Superman          DC   7.3         95
# 1   1980                       Superman II          DC   6.7         88
# 3   1983                      Superman III          DC   4.9         24
# 4   1984                         Supergirl          DC   4.2          8
# 6   1987  Superman IV: The Quest for Peace          DC   3.6         10
# 7   1989                            Batman          DC   7.6         71
# 10  1992                    Batman Returns          DC   7.0         78
# 11  1995                    Batman Forever          DC   5.4         42
# 12  1997                    Batman & Robin          DC   3.6         12
# 13  1997                             Steel          DC   2.7         12
# 22  2004                          Catwoman          DC   3.2         10
# 25  2005                     Batman Begins          DC   8.3         85
# 28  2006                  Superman Returns          DC   6.3         76
# 33  2008                   The Dark Knight          DC   8.9         94
# 37  2009                          Watchmen          DC   7.7         64
# 40  2010                         Jonah Hex          DC   4.6         13
# 42  2011                     Green Lantern          DC   5.9         27
# 46  2012             The Dark Knight Rises          DC   9.1         86
#
#     DataX  UnknownColumn  PretMediulaBilet  NrDeSpectatori  TopPentruAncutare  \
# 0    84.0      7465343.0              2.34    3.190318e+06          222584545
# 1    77.5     14100523.0              2.69    5.241830e+06          227224681
# 3    36.5     13352357.0              3.15    4.238843e+06          233791994
# 4    25.0      5738249.0              3.36    1.707812e+06          235824902
# 6    23.0      5683122.0              3.91    1.453484e+06          242288918
# 7    73.5     40489746.0              3.97    1.019893e+07          246819230
# 10   74.0     45687711.0              4.15    1.100909e+07          255029699
# 11   48.0     52784433.0              4.35    1.213435e+07          262803276
# 12   24.0     42872605.0              4.59    9.340437e+06          267783607
# 13   19.5       870068.0              4.59    1.895573e+05          267783607
# 22   21.0     16728411.0              6.21    2.693786e+06          293045739
# 25   84.0     48745440.0              6.41    7.604593e+06          295753151
# 28   69.5     52535096.0              6.55    8.020625e+06          298593212
# 33   91.5    158411483.0              7.18    2.206288e+07          304374846
# 37   70.5     55214334.0              7.50    7.361911e+06          307006550
# 40   29.5      5379365.0              7.89    6.817953e+05          308745538
# 42   43.0     53174303.0              7.93    6.705461e+06          311591917
# 46   88.5    160887295.0              7.92    2.031405e+07          314055984
# 0    84.0      7465343.0              2.34    3.190318e+06          222584545
# 1    77.5     14100523.0              2.69    5.241830e+06          227224681
# 3    36.5     13352357.0              3.15    4.238843e+06          233791994
# 4    25.0      5738249.0              3.36    1.707812e+06          235824902
# 6    23.0      5683122.0              3.91    1.453484e+06          242288918
# 7    73.5     40489746.0              3.97    1.019893e+07          246819230
# 10   74.0     45687711.0              4.15    1.100909e+07          255029699
# 11   48.0     52784433.0              4.35    1.213435e+07          262803276
# 12   24.0     42872605.0              4.59    9.340437e+06          267783607
# 13   19.5       870068.0              4.59    1.895573e+05          267783607
# 22   21.0     16728411.0              6.21    2.693786e+06          293045739
# 25   84.0     48745440.0              6.41    7.604593e+06          295753151
# 28   69.5     52535096.0              6.55    8.020625e+06          298593212
# 33   91.5    158411483.0              7.18    2.206288e+07          304374846
# 37   70.5     55214334.0              7.50    7.361911e+06          307006550
# 40   29.5      5379365.0              7.89    6.817953e+05          308745538
# 42   43.0     53174303.0              7.93    6.705461e+06          311591917
# 46   88.5    160887295.0              7.92    2.031405e+07          314055984
#
#     IMBD_normalizat  AltRating_normalizat
# 0              0.73                  0.95
# 1              0.67                  0.88
# 3              0.49                  0.24
# 4              0.42                  0.08
# 6              0.36                  0.10
# 7              0.76                  0.71
# 10             0.70                  0.78
# 11             0.54                  0.42
# 12             0.36                  0.12
# 13             0.27                  0.12
# 22             0.32                  0.10
# 25             0.83                  0.85
# 28             0.63                  0.76
# 33             0.89                  0.94
# 37             0.77                  0.64
# 40             0.46                  0.13
# 42             0.59                  0.27
# 46             0.91                  0.86
# 0              0.73                  0.95
# 1              0.67                  0.88
# 3              0.49                  0.24
# 4              0.42                  0.08
# 6              0.36                  0.10
# 7              0.76                  0.71
# 10             0.70                  0.78
# 11             0.54                  0.42
# 12             0.36                  0.12
# 13             0.27                  0.12
# 22             0.32                  0.10
# 25             0.83                  0.85
# 28             0.63                  0.76
# 33             0.89                  0.94
# 37             0.77                  0.64
# 40             0.46                  0.13
# 42             0.59                  0.27
# 46             0.91                  0.86

# %%
#Anul si titlu pentru filmele de la Marvel
new_csv.loc[new_csv['Organizatia'] == 'Marvel'][['An','Titlu']]
# Out:
#       An                                      Titlu
# 5   1986                            Howard the Duck
# 14  1998                                      Blade
# 15  2000                                      X-Men
# 16  2002                                   Blade II
# 17  2002                                 Spider-Man
# 18  2003                                  Daredevil
# 19  2003                                       Hulk
# 20  2003                                         X2
# 21  2004                             Blade: Trinity
# 23  2004                               Spider-Man 2
# 24  2004                               The Punisher
# 26  2005                                    Elektra
# 27  2005                             Fantastic Four
# 29  2006                      X-Men: The Last Stand
# 30  2007  Fantastic Four: Rise of the Silver Surfer
# 31  2007                                Ghost Rider
# 32  2007                               Spider-Man 3
# 34  2008                        The Incredible Hulk
# 35  2008                                   Iron Man
# 36  2008                         Punisher: War Zone
# 38  2009                   X-Men Origins: Wolverine
# 39  2010                                 Iron Man 2
# 41  2011         Captain America: The First Avenger
# 43  2011                                       Thor
# 44  2011                         X-Men: First Class
# 45  2012                      Marvel's The Avengers
# 47  2012           Ghost Rider: Spirit of Vengeance
# 48  2012                     The Amazing Spider-Man
# 5   1986                            Howard the Duck
# 14  1998                                      Blade
# 15  2000                                      X-Men
# 16  2002                                   Blade II
# 17  2002                                 Spider-Man
# 18  2003                                  Daredevil
# 19  2003                                       Hulk
# 20  2003                                         X2
# 21  2004                             Blade: Trinity
# 23  2004                               Spider-Man 2
# 24  2004                               The Punisher
# 26  2005                                    Elektra
# 27  2005                             Fantastic Four
# 29  2006                      X-Men: The Last Stand
# 30  2007  Fantastic Four: Rise of the Silver Surfer
# 31  2007                                Ghost Rider
# 32  2007                               Spider-Man 3
# 34  2008                        The Incredible Hulk
# 35  2008                                   Iron Man
# 36  2008                         Punisher: War Zone
# 38  2009                   X-Men Origins: Wolverine
# 39  2010                                 Iron Man 2
# 41  2011         Captain America: The First Avenger
# 43  2011                                       Thor
# 44  2011                         X-Men: First Class
# 45  2012                      Marvel's The Avengers
# 47  2012           Ghost Rider: Spirit of Vengeance
# 48  2012                     The Amazing Spider-Man

# %%
#graficul pentru PretulMediuLaBilet cu Anul pe axa y. Culoarea liniei sa fie neagra.
plot = new_csv.plot.scatter(x = 'PretMediulaBilet', y = 'An')
z = np.polyfit(x=new_csv.PretMediulaBilet, y=new_csv.An, deg=5) #polinom de gradul 5 inseamna deg=5
p = np.poly1d(z)
trendline = pd.DataFrame(data=p(new_csv.PretMediulaBilet), index=new_csv.PretMediulaBilet)
trendline.plot.line(ax=plot, color='Black')

# %%
TitleDataFrame = DataFrame(csv['Titlu'])

# %%
TitleDataFrame.head(8)
# Out:
#                               Titlu
# 0                          Superman
# 1                       Superman II
# 2                       Swamp Thing
# 3                      Superman III
# 4                         Supergirl
# 5                   Howard the Duck
# 6  Superman IV: The Quest for Peace
# 7                            Batman

# %%
titleSeries = Series(csv['Titlu'])
titleSeries.head(8)
# Out:
# 0                            Superman
# 1                         Superman II
# 2                         Swamp Thing
# 3                        Superman III
# 4                           Supergirl
# 5                     Howard the Duck
# 6    Superman IV: The Quest for Peace
# 7                              Batman
# Name: Titlu, dtype: object

# %% [markdown]
# Concluzie: În urma efectuarii acestei lucrări de laborator am aflat care sunt instrumentele necesare pentru lucrul cu Python și ML și manipularea datelor. Am aflat ce este un dataframe și cu ce se deosebeștie de o serie, cum se normalizează datele, și cum să construim grafice.
