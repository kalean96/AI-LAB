# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
# %matplotlib inline

# %% [markdown]
# De realizat:
# 1. Definiti o serie pandas.
# 2. Definiti un dataframe in pandas.
# 3. Cum veti afisa numai filmele de la DC pentru DataFrame-ul new_csv?
# 4. Cum veti afisa numai anul si titlu pentru filmele de la  Marvel?
# 5. Desenati graficul pentru PretulMediuLaBilet cu Anul pTe axa y. Culoarea liniei sa fie neagra.

# %%
neww_csv = pd.read_csv("imbd_superhero.csv", 
                  header=None, 
                  names=['An', 'Titlu','Organizatia', 'IMBD', 'AltRating', 'DataX', 'UnknownColumn', 'PretMediulaBilet', 'NrDeSpectatori', 'TopPentruAncutare'])

altrating_norm = np.where(neww_csv['IMBD']>=7, 'yes', 'no')
neww_csv.insert(10, 'StatusPrivit', altrating_norm)
neww_csv.head(6)
# Out:
#      An            Titlu Organizatia  IMBD  AltRating  DataX  UnknownColumn  \
# 0  1978         Superman          DC   7.3         95   84.0      7465343.0
# 1  1980      Superman II          DC   6.7         88   77.5     14100523.0
# 2  1982      Swamp Thing          DC   5.3         60   56.5            NaN
# 3  1983     Superman III          DC   4.9         24   36.5     13352357.0
# 4  1984        Supergirl          DC   4.2          8   25.0      5738249.0
# 5  1986  Howard the Duck      Marvel   4.3         16   29.5      5070136.0
#
#    PretMediulaBilet  NrDeSpectatori  TopPentruAncutare StatusPrivit
# 0              2.34     3190317.521          222584545          yes
# 1              2.69     5241830.112          227224681           no
# 2              2.94             NaN          231664458           no
# 3              3.15     4238843.492          233791994           no
# 4              3.36     1707812.202          235824902           no
# ...

# %%
dc = neww_csv[neww_csv['Organizatia']=='DC']
dc.head(5)
# Out:
#      An         Titlu Organizatia  IMBD  AltRating  DataX  UnknownColumn  \
# 0  1978      Superman          DC   7.3         95   84.0      7465343.0
# 1  1980   Superman II          DC   6.7         88   77.5     14100523.0
# 2  1982   Swamp Thing          DC   5.3         60   56.5            NaN
# 3  1983  Superman III          DC   4.9         24   36.5     13352357.0
# 4  1984     Supergirl          DC   4.2          8   25.0      5738249.0
#
#    PretMediulaBilet  NrDeSpectatori  TopPentruAncutare StatusPrivit
# 0              2.34     3190317.521          222584545          yes
# 1              2.69     5241830.112          227224681           no
# 2              2.94             NaN          231664458           no
# 3              3.15     4238843.492          233791994           no
# 4              3.36     1707812.202          235824902           no

# %%
marvel = neww_csv[neww_csv['Organizatia']=='Marvel']
sarc4=pd.DataFrame(marvel)
sarc4=sarc4[['An','Titlu']]
sarc4
# Out:
#       An                                      Titlu
# 5   1986                            Howard the Duck
# 9   1989                               The Punisher
# 14  1998                                      Blade
# 15  2000                                      X-Men
# 16  2002                                   Blade II
# 17  2002                                 Spider-Man
# 18  2003                                  Daredevil
# 19  2003                                       Hulk
# 20  2003                                         X2
# 21  2004                             Blade: Trinity
# 23  2004                               Spider-Man 2
# 24  2004                               The Punisher
# 26  2005                                    Elektra
# 27  2005                             Fantastic Four
# 29  2006                      X-Men: The Last Stand
# 30  2007  Fantastic Four: Rise of the Silver Surfer
# 31  2007                                Ghost Rider
# ...

# %%
new_csv = pd.read_csv("imbd_superhero.csv", 
                  header=None, 
                  names=['An', 'Titlu','Organizatia', 'IMBD', 'AltRating', 'DataX', 'UnknownColumn', 'PretMediulaBilet', 'NrDeSpectatori', 'TopPentruAncutare'])

plot = new_csv.plot.scatter(x = 'An', y = 'IMBD')
z = np.polyfit(x=new_csv.An, y=new_csv.IMBD, deg=5) #polinom de gradul 5 inseamna deg=5
p = np.poly1d(z)
trendline = pd.DataFrame(data=p(new_csv.An), index=new_csv.An)
trendline.plot.line(ax=plot, color='Black')

# %% [markdown]
# Concluzie: La acest laborator am configurat mediul stabil de dezvoltare Python petru Machine learning.
# - Am configurat Python 3 si Pip pentru Windows
# - Am creat mediu virtual 'virtualenv'pentru a separa setarile noastre de codare in care instalam toate pachetele python
# - Am manipulat cu datele de tip csv utilizand numpy si pandas
